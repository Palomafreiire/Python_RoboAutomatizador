# %% [markdown]
# Processo seletivo QCA
#
# Tipo Robô: Extração de relatório
# Site para extrair a planilha: http://dados.recife.pe.gov.br/organization
# Email para mandar a planilha: fernandofigueiredo@queirozcavalcanti.adv.br

# %%
import pyautogui
import pyperclip
import time


pyautogui.PAUSE = 1

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("http://dados.recife.pe.gov.br/organization")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(3)

pyautogui.click(x=543, y=391)
pyautogui.write("infraestrutura")
pyautogui.click(x=1173, y=389)

time.sleep(2)

pyautogui.click(x=726, y=607)

time.sleep(2)

pyautogui.click(x=484, y=623)

time.sleep(2)

pyautogui.click(x=1194, y=642)

time.sleep(2)

pyautogui.click(x=1156, y=714)

#enviar o email:

time.sleep(5)

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://outlook.live.com/mail/0/")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(10)

pyautogui.click(x=175, y=175)

time.sleep(7)


#email
pyautogui.write("fernandofigueiredo@queirozcavalcanti.adv.br")
pyautogui.press("tab")
pyautogui.press("tab")

time.sleep(2)

#Assunto
pyautogui.write("Processo seletivo Paloma Freire com Python")
pyautogui.press("tab")

time.sleep(2)

#Corpo do email
 
texto = """
Prezados,

Segue em anexo a planilha de acordo com o que foi requisitado, caso queira ver o codigo fonte
ele esta no meu github em https://github.com/Palomafreiire

Att,
Paloma Freire."""

pyautogui.write(texto)

#anexar arquivo
time.sleep(5)

pyautogui.click(x=517, y=596)

time.sleep(5)

pyautogui.click(x=598, y=489)

time.sleep(5)

pyautogui.click(x=220, y=291)
pyautogui.press("enter")

#enviar

time.sleep(3)

pyautogui.click(x=301, y=597)

# %%
#posição dos elementos:
time.sleep(5)
pyautogui.position()
